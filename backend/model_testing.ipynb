# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances, silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.spatial.distance import correlation
from tqdm.notebook import tqdm
import pickle
import os

# %% [markdown]
# # Data Preprocessing

# %%
data = pd.read_csv('..frontend/data/dataset.csv', index_col=0)
data.drop_duplicates(subset='track_id')
features = ['track_name', 'artists', 'popularity', 'track_genre', 'danceability', 'loudness', 'acousticness', 'valence', 'tempo']
X = data[features].copy()
X.drop_duplicates(subset=['track_name', 'artists'], keep='first', inplace=True)
X.reset_index(drop=True, inplace=True)  # fix indices after removing duplicates

# Standardize data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[['popularity', 'danceability', 'loudness', 'acousticness', 'valence', 'tempo']])
cos_scaled = X_scaled / np.linalg.norm(X_scaled, axis=1)[:, np.newaxis]

euc_model = KMeans(n_clusters=9, init="k-means++", random_state=42)
cos_model = KMeans(n_clusters=9, init="k-means++", random_state=42)

# %%
with open('models/eucd.pkl', 'rb') as file:
    euc_model = pickle.load(file)
with open('models/cos.pkl', 'rb') as file:
    cos_model = pickle.load(file)

clusters = euc_model.predict(X_scaled)
results = X.copy()
results['cluster'] = clusters.astype(str)

# cos_model.predict(cos_scaled)
# results['cluster'] = clusters.astype(str)

"""
with open('eucd.pkl', 'wb') as handle:
    pickle.dump(euc_model, handle)
with open('cos.pkl', 'wb') as handle:
    pickle.dump(cos_model, handle)
"""
# Out:
# "\nwith open('eucd.pkl', 'wb') as handle:\n    pickle.dump(euc_model, handle)\nwith open('cos.pkl', 'wb') as handle:\n    pickle.dump(cos_model, handle)\n"

# %%
results[results['cluster'] == '2'].track_genre.value_counts()
# Out:
# track_genre
# salsa          482
# forro          380
# dancehall      355
# children       341
# sertanejo      308
#               ...
# heavy-metal      5
# metalcore        4
# ambient          4
# romance          2
# black-metal      1
# Name: count, Length: 108, dtype: int64

# %% [markdown]
# # Create Song Search

# %%
title = 'Hello'
artist = 'Adele'
X[X['track_name'].str.contains(title, na=False, case=False) & X['artists'].str.contains(artist, na=False, case=False)]
# Out:
#      track_name artists  popularity track_genre  danceability  loudness  \
# 9357      Hello   Adele          74     british         0.578    -6.134
#
#       acousticness  valence   tempo
# 9357          0.33    0.288  78.991

# %%
data[data['track_name'].str.contains(title, na=False, case=False) & data['artists'].str.contains(artist, na=False, case=False)]
# Out:
#                      track_id                             artists  \
# 2003   2QjOHCTQ1Jl3zawyYOpxh6                   The Neighbourhood
# 2804   5YCPqMoXNlPeUJ9fm1dlz3        The Neighbourhood;Young Saab
# 3003   2QjOHCTQ1Jl3zawyYOpxh6                   The Neighbourhood
# 15743  3NKUFgqI2sMrtIRGx5IHwx  untrusted;creamy;11:11 Music Group
# 15774  2Wp8cVfQ9g9Fl1e6MDxXSG                               89ine
# 32223  6siDDghVE7fxel5o7fE4OF             Gaullin;Julian Perretta
# 36857  3ezoEY4TKU8frUXAYFJstC                            Remzcore
# 48508  3ezoEY4TKU8frUXAYFJstC                            Remzcore
# 55681  0BXzHqVTlb88KmbgM56H70           Swattrex;Lofi By Swattrex
# 81853  2QjOHCTQ1Jl3zawyYOpxh6                   The Neighbourhood
# 91002  2QjOHCTQ1Jl3zawyYOpxh6                   The Neighbourhood
# 94669  2Wp8cVfQ9g9Fl1e6MDxXSG                               89ine
# 94694  3NKUFgqI2sMrtIRGx5IHwx  untrusted;creamy;11:11 Music Group
#
#                                          album_name  \
# 2003                                    I Love You.
# 2804             Sweater Weather (Young Saab Remix)
# 3003                                    I Love You.
# 15743  sweater weather / i wanna be your girlfriend
# 15774                  Sweater Weather (Lofi Remix)
# 32223                               Sweater Weather
# 36857                               Sweater Weather
# 48508                               Sweater Weather
# 55681                               Sweater Weather
# 81853                                   I Love You.
# 91002                                   I Love You.
# 94669                  Sweater Weather (Lofi Remix)
# 94694  sweater weather / i wanna be your girlfriend
#
#                                          track_name  popularity  duration_ms  \
# 2003                                Sweater Weather          93       240400
# 2804             Sweater Weather - Young Saab Remix          61       267270
# 3003                                Sweater Weather          93       240400
# 15743  sweater weather / i wanna be your girlfriend          57       235161
# 15774                  Sweater Weather (Lofi Remix)          45       215872
# 32223                               Sweater Weather          63       171133
# 36857                               Sweater Weather          61       230389
# 48508                               Sweater Weather          61       230389
# 55681                               Sweater Weather           0       305117
# 81853                               Sweater Weather          93       240400
# 91002                               Sweater Weather          93       240400
# 94669                  Sweater Weather (Lofi Remix)          45       215872
# 94694  sweater weather / i wanna be your girlfriend          57       235161
#
#        explicit  danceability  energy  key  loudness  mode  speechiness  \
# 2003      False         0.612   0.807   10    -2.810     1       0.0336
# 2804      False         0.583   0.954    7    -4.179     0       0.0788
# 3003      False         0.612   0.807   10    -2.810     1       0.0336
# 15743     False         0.655   0.538   10    -7.991     1       0.0378
# 15774     False         0.603   0.296    0   -16.694     0       0.0424
# 32223     False         0.570   0.873    5    -5.188     0       0.0700
# 36857     False         0.507   0.985    1    -0.181     0       0.1920
# 48508     False         0.507   0.985    1    -0.181     0       0.1920
# 55681     False         0.464   0.397    1   -14.002     1       0.0468
# 81853     False         0.612   0.807   10    -2.810     1       0.0336
# 91002     False         0.612   0.807   10    -2.810     1       0.0336
# 94669     False         0.603   0.296    0   -16.694     0       0.0424
# 94694     False         0.655   0.538   10    -7.991     1       0.0378
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 2003       0.049500          0.017700    0.1010   0.3980  124.053
# 2804       0.000553          0.243000    0.4140   0.4210  124.029
# 3003       0.049500          0.017700    0.1010   0.3980  124.053
# 15743      0.299000          0.393000    0.0762   0.3290  124.045
# 15774      0.103000          0.235000    0.1060   0.0760   96.018
# 32223      0.008530          0.000000    0.3650   0.2360  125.086
# 36857      0.046700          0.000394    0.1070   0.2300   95.000
# 48508      0.046700          0.000394    0.1070   0.2300   95.000
# 55681      0.208000          0.865000    0.1120   0.0541   96.035
# 81853      0.049500          0.017700    0.1010   0.3980  124.053
# 91002      0.049500          0.017700    0.1010   0.3980  124.053
# 94669      0.103000          0.235000    0.1060   0.0760   96.018
# 94694      0.299000          0.393000    0.0762   0.3290  124.045
#
#        time_signature  track_genre
# 2003                4     alt-rock
# 2804                4     alt-rock
# 3003                4  alternative
# 15743               4        chill
# 15774               4        chill
# 32223               4   electronic
# 36857               4       french
# 48508               4     hardcore
# 55681               4       indian
# 81853               4          pop
# 91002               4         rock
# 94669               4          sad
# 94694               4          sad

# %% [markdown]
# # Create Playlist Song Recommendation

# %%
most_similar = np.argpartition(np.mean((X_scaled - X_scaled[9357].T)**2, axis=1), kth=7)[:7]
results.iloc[most_similar]
# Out:
#                                    track_name                    artists  \
# 9390                        Chasing Pavements                      Adele
# 9357                                    Hello                      Adele
# 16793                               The Bones               Maren Morris
# 16766                 The Bones - with Hozier        Maren Morris;Hozier
# 25071                                    Burn             Ellie Goulding
# 28021  You're the Inspiration - 2006 Remaster                    Chicago
# 61452                     Tera Yaar Hoon Main  Rochak Kohli;Arijit Singh
#
#        popularity track_genre  danceability  loudness  acousticness  valence  \
# 9390           74     british         0.616    -6.092         0.291    0.325
# 9357           74     british         0.578    -6.134         0.330    0.288
# 16793          75     country         0.612    -6.642         0.278    0.334
# 16766          71     country         0.561    -6.000         0.286    0.355
# 25071          71         edm         0.559    -5.031         0.310    0.329
# 28021          73        folk         0.583    -6.364         0.368    0.388
# 61452          66         pop         0.559    -5.525         0.340    0.309
#
#         tempo cluster
# 9390   80.030       6
# 9357   78.991       6
# 16793  77.004       6
# 16766  76.826       6
# 25071  87.016       6
# 28021  74.008       6
# 61452  83.978       6

# %%
# Create a playlist based on the index of the songs
playlist = [9357] # [3884, 48383, 48625, 50201]

# Find groups each correspond to
songs = results.iloc[playlist]
clusters = euc_model.predict(X_scaled[playlist])
majority = np.argmax(np.bincount(clusters))

# %% [markdown]
# ## Find the nearest song based on the correlation distance between the two songs
# Intuitively, this is because similar songs won't have exactly the same absolute values between the values of their attributes, but instead they should have similar relative values between their features (i.e. similar feels and vibes). Therefore, it makes sense to instead consider their correlation distance with each other.

# %%
# For each song in majority cluster, pick the songs that are cloest to the songs in the playlist
song_score = []
indices = results[results['cluster'] == str(majority)].index
N = len(playlist)
for song in indices:
    score = float('inf')
    for liked_song in playlist:
        score = min(score, correlation(X_scaled[song], X_scaled[liked_song])) # min(score, np.mean((X_scaled[song] - X_scaled[liked_song])**2))
    song_score.append(score)

# %%
results.iloc[playlist]
# Out:
#      track_name artists  popularity track_genre  danceability  loudness  \
# 9357      Hello   Adele          74     british         0.578    -6.134
#
#       acousticness  valence   tempo cluster
# 9357          0.33    0.288  78.991       6

# %%
top_k = len(playlist) + 10
most_similar = np.argsort(song_score)[len(playlist):len(playlist) + 10]# np.argpartition(song_score, top_k)[:top_k]
results.iloc[indices[most_similar]]
# Out:
#                                              track_name  \
# 61309  Mera Dil Bhi Kitna Pagal Hai - Recreated Version
# 9390                                  Chasing Pavements
# 27030                                        ghost girl
# 61452                               Tera Yaar Hoon Main
# 15                     Falling in Love at a Coffee Shop
# 61463                                    Temporary pyar
# 25071                                              Burn
# 16793                                         The Bones
# 41342                                       Sohne Lagde
# 16766                           The Bones - with Hozier
#
#                             artists  popularity track_genre  danceability  \
# 61309                    Stebin Ben          70         pop         0.601
# 9390                          Adele          74     british         0.616
# 27030                      Lil Peep          66         emo         0.520
# 61452     Rochak Kohli;Arijit Singh          66         pop         0.559
# 15                      Landon Pigg          58    acoustic         0.489
# 61463                          Kaka          65         pop         0.531
# 25071                Ellie Goulding          71         edm         0.559
# 16793                  Maren Morris          75     country         0.612
# 41342  Sidhu Moose Wala;The PropheC          64     hip-hop         0.589
# 16766           Maren Morris;Hozier          71     country         0.561
#
#        loudness  acousticness  valence   tempo cluster
# 61309    -5.987         0.333    0.375  94.017       6
# 9390     -6.092         0.291    0.325  80.030       6
# 27030    -7.069         0.281    0.317  80.035       6
# 61452    -5.525         0.340    0.309  83.978       6
# 15       -7.933         0.200    0.238  83.457       6
# 61463    -7.213         0.281    0.339  79.942       6
# 25071    -5.031         0.310    0.329  87.016       6
# 16793    -6.642         0.278    0.334  77.004       6
# 41342    -5.651         0.354    0.327  84.384       6
# 16766    -6.000         0.286    0.355  76.826       6

# %% [markdown]
# # Genre Evaluation
# Based on a custom-made grouping of the genres, evaluate the performance of the model.

# %%
# Custom genre groupings for each possible genre in the dataset
genre_groupings = [
    ['acoustic', 'folk', 'singer-songwriter', 'bluegrass', 'country', 'honky-tonk', 'rockabilly', 'study', 'guitar', 'piano', 'new-age', 'ambient', 'sleep', 'chill'],
    ['rock', 'alt-rock', 'alternative', 'hard-rock', 'grunge', 'punk', 'punk-rock', 'emo', 'psych-rock', 'rock-n-roll', 'indie', 'indie-pop', 'power-pop', 'goth', 'industrial'],
    ['metal', 'black-metal', 'death-metal', 'heavy-metal', 'hardcore', 'metalcore', 'grindcore', 'hardstyle'],
    ['electronic', 'edm', 'dance', 'electro', 'house', 'deep-house', 'chicago-house', 'progressive-house', 'techno', 'detroit-techno', 'minimal-techno', 'trance', 'dubstep', 'drum-and-bass', 'breakbeat', 'idm', 'trip-hop', 'garage', 'club', 'party', 'synth-pop', 'disco'],
    ['hip-hop', 'r-n-b', 'soul', 'funk', 'groove', 'reggae', 'dancehall', 'dub'],
    ['jazz', 'blues', 'classical', 'opera', 'show-tunes', 'disney', 'pop-film', 'romance', 'sad', 'happy'],
    ['pop', 'k-pop', 'j-pop', 'j-dance', 'j-idol', 'j-rock', 'anime', 'cantopop', 'mandopop'],
    ['latin', 'latino', 'salsa', 'samba', 'brazil', 'mpb', 'pagode', 'forro', 'sertanejo', 'tango', 'spanish', 'afrobeat', 'reggaeton'],
    ['world-music', 'children', 'kids', 'comedy', 'french', 'german', 'indian', 'iranian', 'malay', 'turkish', 'british', 'swedish']
]

# Create genre to group dictionary
genre_groups = {}
for idx, group in enumerate(genre_groupings):
    for genre in group:
        genre_groups[genre] = idx

# %%
# Find group majority
group_indices = [genre_groups[genre] for genre in results.iloc[playlist].track_genre]
counts = np.bincount(group_indices)
majority_group = np.argmax(counts)

# Calculate the ratio of the recommended songs that are in the same genre group (higher is better)
total = top_k - len(playlist)
in_group = sum([1 for genre in results.iloc[indices[most_similar]][len(playlist)-1:].track_genre if genre_groups[genre] == majority_group])
print(in_group / total)
# Out:
# 0.1
